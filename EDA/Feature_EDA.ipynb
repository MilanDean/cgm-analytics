# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = '../data/output/features/synthetic_dataset_features.csv'
df = pd.read_csv(file)

# %%
df.head()
# Out:
#      subject          start_block            end_block  n_samples  \
# 0  adult#001  2023-06-11 00:00:00  2023-06-11 00:29:00         30
# 1  adult#001  2023-06-11 00:30:00  2023-06-11 00:59:00         30
# 2  adult#001  2023-06-11 01:00:00  2023-06-11 01:29:00         30
# 3  adult#001  2023-06-11 01:30:00  2023-06-11 01:59:00         30
# 4  adult#001  2023-06-11 02:00:00  2023-06-11 02:29:00         30
#
#    label(meal)        mean      median         min         max       std  ...  \
# 0            0  145.124322  144.697984  137.354088  155.333949  4.619014  ...
# 1            0  135.698653  135.516728  131.903305  139.942604  2.830924  ...
# 2            0  131.241825  130.640397  123.907015  140.390022  5.734882  ...
# 3            0  136.505991  136.443768  134.129041  140.413370  1.903254  ...
# 4            0  139.172054  137.544594  136.229058  145.880003  3.368929  ...
#
#    ROC_median  very_low_range  low_range  target_range  high_range  \
# ...

# %%
for c in df.columns.tolist()[5:]:
    plt.figure()
    sns.boxplot(y = df[c], x = df['label(meal)'])
# Out:
# /Users/dimitriospsaltos/.conda/envs/RITL_code/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
for c in df.columns.tolist()[5:]:
    plt.figure()
    sns.histplot(x = df[c], hue = df['label(meal)'])
# Out:
# /Users/dimitriospsaltos/.conda/envs/RITL_code/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
